# %%
from KERNEL import *
from BLUR import *
from GCV import *
from ESF import *
from EVALSIG import *
from TKV_REG import *
from TV_REG import *

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from tqdm.notebook import tqdm

sns.set_palette('colorblind')
sns.set_context("paper")
sns.set_style('white')
#, 'size': 11
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

esffunc = logistic

# %%
import cv2 as cv
mat = cv.imread("calibrationTarget.tiff", cv.IMREAD_GRAYSCALE)
#mat = mat[0:40, 420:460]

# %%
test = mat.reshape(np.prod(mat.shape), 1)
A = kernel(test.size, 9)
blurred = blur(test, A, True, 0.1)
blurred = blurred.reshape(mat.shape[0], mat.shape[1])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[38], line 2
#       1 test = mat.reshape(np.prod(mat.shape), 1)
# ----> 2 A = kernel(test.size, 9)
#       3 blurred = blur(test, A, True, 0.1)
#       4 blurred = blurred.reshape(mat.shape[0], mat.shape[1])
#
# File ~\DataspellProjects\REU_Deblur\KERNEL.py:10, in kernel(n, sigma)
#       8 a = np.diff(st.norm.cdf(tmp))
#       9 a = a/sum(a)/2
# ---> 10 return la.toeplitz(a)
#
# File ~\anaconda3\Lib\site-packages\scipy\linalg\_special_matrices.py:199, in toeplitz(c, r)
#     197 out_shp = len(c), len(r)
#     198 n = vals.strides[0]
# --> 199 return as_strided(vals[len(c)-1:], shape=out_shp, strides=(-n, n)).copy()
#
# MemoryError: Unable to allocate 396. GiB for an array with shape (230400, 230400) and data type float64

# %%
plt.plot(mat)
plt.plot(blurred)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 plt.plot(mat)
#       2 plt.plot(blurred)
# ----> 3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# ...

# %%
plt.imshow(mat)
plt.show()

# %%
plt.imshow(blurred)
plt.show()

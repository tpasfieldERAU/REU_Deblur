# %%
import matplotlib.pyplot as plt
import numpy as np
with open('WoodTestStep.tiff', 'rb') as pgmf:
    im = plt.imread(pgmf)

img = im[110:140, 70:440]
plt.imshow(img)

# %%
from KERNEL import kernel
from BLUR import blur
A = kernel(img.shape[0], 10)
plt.imshow(A)
b = blur(img, A, True, 0.012)

plt.imshow(b)
plt.show()

plt.plot(img[12,:])
plt.show()

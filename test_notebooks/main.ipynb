# %%
import matplotlib.pyplot as plt
import numpy as np

file = open('standard_signals.csv', 'r')
for i in range(8):file.readline()
val = file.readline().split(',')
val.pop()
x = [float(i) for i in val]
x = np.asarray(x).reshape(len(x),1)

# %%
from TV_REG import *
from KERNEL import *
from BLUR import *
from TKV_REG import *
A = kernel(x.shape[0], 10)
b = blur(x, A, True, 0.012)
#x_re = tkv_regularize(b, A, 0.0007)

# %%
plt.plot(x)
plt.plot(b)
#plt.plot(x_re)
plt.ylim([0, 1.1])
#plt.legend(['Original', 'Blur+Noise', 'Reconstructed'])
plt.show()

# %%
from GCV import run_gcv
x_re1, gcv = run_gcv(A, b, tkv_regularize)
print(f"Optimal alpha: {gcv}")
print('Complete')
# Out:
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# Optimal alpha: 4.449617160996482e-05
# Complete

# %%
plt.plot(x)
plt.plot(b)
plt.plot(x_re1)
plt.ylim([0, 1.1])
plt.legend(['Original', 'Blur+Noise', 'Reconstructed'])
plt.show()

# %%
x_re2, gcv = run_gcv(A, b, tv_regularize)
print(f"Optimal alpha: {gcv}")
print('Complete')
# Out:
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# STEP
# Optimal alpha: 4.557445139790014e-05
# Complete

# %%
plt.plot(x)
plt.plot(b)
plt.plot(x_re2)
plt.ylim([0, 1.1])
plt.legend(['Original', 'Blur+Noise', 'Reconstructed'])
plt.show()
